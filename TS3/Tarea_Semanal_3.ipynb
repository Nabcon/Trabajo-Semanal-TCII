# %% [markdown]
# #### Teoría de Circuitos II
#
# # Tarea Semanal 3 - Actividad N°4
#
# #### Por Nahuel Braian Contreras

# %% [markdown]
# ### Actividad
# Los cáclulos del ejercicios se realizaron en OneNote

# %%
from IPython.display import IFrame
IFrame("TS3 - Ejercicio 4.pdf", width=900, height=900)
# Out:
#         <iframe
#             width="900"
#             height="900"
#             src="TS3 - Ejercicio 4.pdf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Simulación en Python
# Utilizamos python para poder graficar la respuesta en modulo y fase

# %%
import scipy.signal as sig
import numpy as np
import matplotlib.pyplot as plt
nn = 4
alfa_max = 1 # dB
e = np.sqrt(10**(alfa_max/10)-1)

wb = 1/(e**(-1/nn))

num = [1, 0, 0, 0, 0]
den = np.convolve([1, 2*np.cos(np.pi/8)*wb, wb**2], [1, 2*np.cos(np.pi*3/8)*wb, wb**2])

sys = sig.TransferFunction(num, den)

f = np.logspace(-1, 1,1000)
w, mag, phase = sig.bode(sys,f)

fig, (ax1,ax2) = plt.subplots(nrows=2 , ncols=1, sharex=False)
fig.set_size_inches(16,12)
ax1.semilogx(w,mag,label='|T(w)|')
ax1.grid(True)
ax1.set_title('Magnitude Response')
ax1.set_ylabel('Magnitude[dB]')
ax1.set_yticks([-70,-50,-35,-30,-10,-1])
ax1.set_xticks([2/7,1])
ax1.set_xticklabels(['$\omega_{NS} = 2/7$','$\omega_{NP} = 1$'])
ax1.set_ylabel('Magnitude[dB]')
ax1.legend()

ax2.semilogx(w, phase,color='red',label='ang[T(w)]')
ax2.grid(True)
ax2.set_title('Phase Response')
ax2.set_ylabel('Phase[deg]')
ax2.set_xticks([2/7,1])
ax2.set_xticklabels(['$\omega_{NS} = 2/7$','$\omega_{NP} = 1$'])
ax2.legend()

# %% [markdown]
# **Diagrama de Polos y Ceros**
# <img src="Polos_ceros.png">

# %% [markdown]
# ### Simulacion Circuital
#
# **Circuito**
#
#  No fue necesario bufferear cada etapa, ya que la salida del operacional utilizado en el girador (representando una bobina) realiza esa función.
#
# <img src="Circuito.png">
#
# **Graficos**
#
# Observamos que en circuito fitro pasa alto pasivo con bobina activada obtenemos en la Frecuencia de Paso **(3.5KHz)** una atenuación muy cercana a -1dB
#
# <img src="Circuito_1db.png">
#
# Tambien en la Frecuencia de Stop **(1KHz)**, tenemos una atenuación superior a los 35dB solicitados
#
# <img src="Circuito_1k.png">
